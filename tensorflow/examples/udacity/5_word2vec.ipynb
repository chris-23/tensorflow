# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.086908
# Nearest to UNK: hummel, kaunda, malfunctions, karts, collected, botham, aiken, tf,
# Nearest to from: interception, portrayal, shielding, albrecht, executives, indispensable, ogg, sax,
# Nearest to time: reincarnated, deportation, vases, tms, sena, distinctly, administered, quarrels,
# Nearest to with: goliath, mounted, wolof, intermediate, trisha, adaptations, emigrant, misdemeanors,
# Nearest to there: theft, maximus, overwhelm, kaifu, zapatistas, v, champion, golden,
# Nearest to such: archtop, compile, mug, obese, deut, falstaff, couplet, shrine,
# Nearest to d: gibeon, mazarin, missouri, heinz, appletalk, sinned, unchallenged, kosi,
# Nearest to new: imprinted, fianna, arbitrate, winograd, affair, tijuana, consultations, unchangeable,
# Nearest to use: oceanography, islands, lovell, resurrect, vesicle, fire, compelled, levies,
# Nearest to in: monograph, grain, milt, organizer, certainty, cushions, fructose, bloomfield,
# Nearest to used: griswold, revolutions, geophysical, stain, socket, bentham, digitization, exponentially,
# Nearest to their: designed, moonraker, possum, cataloguing, mariano, rounders, sore, garcia,
# Nearest to between: aiken, solenoid, noam, tei, represented, shawl, malvales, soldiers,
# Nearest to during: transcribe, deployment, roommates, unlikely, german, prat, bateson, fetish,
# Nearest to four: griffon, opinion, dans, fayed, shepherd, scriptures, fetuses, oily,
# Nearest to been: ris, featured, above, minstrels, spinster, bowmen, herself, carps,
# Average loss at step 2000: 4.364103
# Average loss at step 4000: 3.870108
# Average loss at step 6000: 3.791971
# Average loss at step 8000: 3.681797
# Average loss at step 10000: 3.615783
# Nearest to UNK: distinguishing, oscar, migrant, boxcar, fulfilled, pyramidal, schengen, rearden,
# Nearest to from: aer, in, by, arrogant, albrecht, into, vanity, untrue,
# Nearest to time: phages, objectors, chesapeake, cores, quarrels, partisan, queer, administered,
# Nearest to with: goliath, in, for, into, ethel, by, mating, salient,
# Nearest to there: it, kaifu, they, diogo, he, mehmet, archivers, incorporation,
# Nearest to such: well, escu, vil, compile, tempest, backs, westernmost, mcgregor,
# Nearest to d: b, gibeon, kosi, heinz, appletalk, mythologie, qualification, unchallenged,
# Nearest to new: disposed, automation, adventists, nadia, jabberwocky, division, won, prophase,
# Nearest to use: adaption, compelled, areas, eunuch, consulate, oceanography, fascination, linen,
# Nearest to in: on, of, at, with, for, decarlo, by, and,
# Nearest to used: found, griswold, honduras, scales, smoking, geophysical, bentham, curses,
# Nearest to their: his, its, the, domineering, serial, her, possum, bosom,
# Nearest to between: noam, fluorine, detachable, sanger, saturdays, solenoid, observational, crustacean,
# Nearest to during: deployment, by, truetype, prat, breaking, after, pink, transcribe,
# Nearest to four: six, eight, five, three, seven, nine, zero, two,
# Nearest to been: was, minstrels, spinster, pittsburg, developed, ris, endings, andromeda,
# Average loss at step 12000: 3.603249
# Average loss at step 14000: 3.569473
# Average loss at step 16000: 3.411073
# Average loss at step 18000: 3.451789
# Average loss at step 20000: 3.537658
# Nearest to UNK: woodside, sandwich, chipping, maneuver, lend, connoisseurs, pesky, avail,
# Nearest to from: into, after, drenthe, at, vanity, under, and, with,
# Nearest to time: year, chesapeake, objectors, way, patent, day, emmett, phages,
# Nearest to with: for, in, accented, into, salient, catacombs, and, by,
# Nearest to there: they, it, he, kaifu, which, we, mehmet, not,
# Nearest to such: well, tempest, known, these, vil, escu, humphries, tubular,
# Nearest to d: b, kosi, bittering, and, instants, gibeon, birger, herbs,
# Nearest to new: automation, necessity, presently, molecule, night, disposed, naive, adventists,
# Nearest to use: areas, adaption, eunuch, compelled, hands, consulate, rehab, phosphoric,
# Nearest to in: at, on, and, during, decarlo, with, of, monetary,
# Nearest to used: found, known, scales, smoking, honduras, griswold, curses, geophysical,
# Nearest to their: his, its, her, the, several, our, domineering, motet,
# Nearest to between: saturdays, fluorine, noam, with, and, including, into, laurentian,
# Nearest to during: by, after, in, pink, roommates, deployment, prat, truetype,
# Nearest to four: six, seven, five, eight, three, two, nine, zero,
# Nearest to been: become, be, pittsburg, was, spinster, endings, mainframes, minstrels,
# Average loss at step 22000: 3.504094
# Average loss at step 24000: 3.488509
# Average loss at step 26000: 3.479108
# Average loss at step 28000: 3.477422
# Average loss at step 30000: 3.499645
# Nearest to UNK: rearden, boxcar, pedagogical, perfume, carmel, e, wimp, o,
# Nearest to from: into, aer, through, in, vanity, of, with, and,
# Nearest to time: year, chesapeake, day, way, objectors, orang, phages, deportation,
# Nearest to with: between, in, through, goliath, when, for, by, from,
# Nearest to there: they, it, he, still, often, kaifu, we, also,
# Nearest to such: well, these, known, tempest, other, vil, many, some,
# Nearest to d: b, kosi, gibeon, bittering, instants, herbs, szl, appletalk,
# Nearest to new: necessity, automation, presently, waltz, adventists, city, lords, imprinted,
# Nearest to use: rehab, support, areas, adaption, epigram, newer, consulate, cruelty,
# Nearest to in: at, on, during, with, from, splintered, and, of,
# Nearest to used: found, known, scales, honduras, regarded, griswold, held, berkeley,
# Nearest to their: its, his, her, the, our, these, some, spherical,
# Nearest to between: with, in, fluorine, saturdays, into, before, including, over,
# Nearest to during: after, in, when, pink, truetype, before, by, on,
# Nearest to four: five, eight, seven, three, six, two, nine, zero,
# Nearest to been: become, be, was, were, pittsburg, mainframes, prejudicial, spinster,
# Average loss at step 32000: 3.499730
# Average loss at step 34000: 3.496655
# Average loss at step 36000: 3.453399
# Average loss at step 38000: 3.299721
# Average loss at step 40000: 3.427167
# Nearest to UNK: b, tougher, singer, bibliography, johnson, barely, missionary, oliphant,
# Nearest to from: into, in, through, aer, vanity, of, for, predictably,
# Nearest to time: way, year, day, chesapeake, institution, diaries, objectors, distance,
# Nearest to with: between, by, without, goliath, while, on, virginity, django,
# Nearest to there: they, it, he, now, still, often, she, we,
# Nearest to such: well, known, tempest, including, these, regarded, defined, vil,
# Nearest to d: b, kosi, herbs, instants, appletalk, j, gibeon, missouri,
# Nearest to new: necessity, nadia, sabha, city, trilogy, individualistic, formation, translation,
# Nearest to use: eunuch, support, cruelty, adaption, rehab, consulate, newer, areas,
# Nearest to in: on, of, from, between, involuntarily, during, decarlo, numerical,
# Nearest to used: found, known, held, possible, reported, glas, considered, designed,
# Nearest to their: its, his, her, the, our, these, some, spherical,
# Nearest to between: with, in, fluorine, into, saturdays, from, before, through,
# Nearest to during: after, before, in, when, pink, under, at, disdained,
# Nearest to four: six, three, five, two, seven, eight, nine, one,
# Nearest to been: become, be, was, mainframes, already, never, pittsburg, prejudicial,
# Average loss at step 42000: 3.436720
# Average loss at step 44000: 3.450716
# Average loss at step 46000: 3.453745
# Average loss at step 48000: 3.354510
# Average loss at step 50000: 3.383946
# Nearest to UNK: aiken, unlicensed, von, bad, et, rumba, dry, woodside,
# Nearest to from: into, aer, in, through, under, after, during, since,
# Nearest to time: way, year, day, diaries, institution, objectors, distance, oregon,
# Nearest to with: between, by, through, accented, boat, elevates, vih, khanum,
# Nearest to there: it, they, he, now, she, we, often, still,
# Nearest to such: well, these, known, tempest, many, regarded, vil, defined,
# Nearest to d: b, e, j, instants, g, boring, kosi, herbs,
# Nearest to new: sabha, great, old, studio, christian, savages, descendents, herat,
# Nearest to use: support, adaption, rehab, share, homilies, construction, inhabitants, eunuch,
# Nearest to in: during, within, of, from, on, since, and, including,
# Nearest to used: known, found, designed, written, held, possible, glas, referred,
# Nearest to their: its, his, her, our, the, whose, your, acceptors,
# Nearest to between: with, fluorine, into, particularity, within, including, saturdays, through,
# Nearest to during: after, in, before, when, from, until, under, pilsener,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to been: become, be, was, were, pittsburg, prejudicial, mainframes, andromeda,
# Average loss at step 52000: 3.439527
# Average loss at step 54000: 3.429441
# Average loss at step 56000: 3.441734
# Average loss at step 58000: 3.399578
# Average loss at step 60000: 3.391178
# Nearest to UNK: pita, cliffs, rebelling, afars, ord, abu, cynthia, rigged,
# Nearest to from: into, through, aer, under, cade, crusaders, callous, after,
# Nearest to time: way, year, oregon, objectors, thing, day, chesapeake, reports,
# Nearest to with: between, among, salient, kandinsky, accented, daoud, through, siding,
# Nearest to there: they, it, now, she, still, we, he, often,
# Nearest to such: these, well, tempest, known, many, including, regarded, fistula,
# Nearest to d: b, j, p, e, m, w, h, f,
# Nearest to new: sabha, gifford, translation, bug, commuted, stem, previous, columba,
# Nearest to use: support, rehab, share, epigram, practice, cavern, allow, maguire,
# Nearest to in: within, during, of, since, on, including, at, typically,
# Nearest to used: known, found, held, designed, regarded, called, written, considered,
# Nearest to their: its, his, her, our, the, whose, your, some,
# Nearest to between: with, into, within, through, fluorine, in, poindexter, over,
# Nearest to during: after, in, before, when, despite, until, at, throughout,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to been: become, be, was, already, andromeda, prejudicial, had, pittsburg,
# Average loss at step 62000: 3.242649
# Average loss at step 64000: 3.255488
# Average loss at step 66000: 3.402206
# Average loss at step 68000: 3.393183
# Average loss at step 70000: 3.357338
# Nearest to UNK: wimp, schneider, distraught, trumbo, reactant, permissive, pe, tique,
# Nearest to from: through, into, under, in, toward, by, aer, callous,
# Nearest to time: diaries, way, year, institution, oregon, however, thing, chesapeake,
# Nearest to with: between, among, django, goliath, daoud, nag, through, salient,
# Nearest to there: it, they, we, now, still, she, he, often,
# Nearest to such: these, well, tempest, known, many, including, other, regarded,
# Nearest to d: b, j, mythologie, w, p, e, drum, h,
# Nearest to new: gifford, certain, sabha, translation, savages, christian, dramatization, mesoamerica,
# Nearest to use: share, support, most, rehab, cavern, allow, homilies, grin,
# Nearest to in: within, during, on, for, including, at, from, until,
# Nearest to used: known, found, described, written, held, designed, regarded, called,
# Nearest to their: its, his, her, our, the, your, some, these,
# Nearest to between: with, within, into, among, through, poindexter, in, involves,
# Nearest to during: after, before, until, in, despite, at, throughout, outside,
# Nearest to four: five, six, three, eight, seven, two, zero, nine,
# Nearest to been: become, be, was, recently, were, already, andromeda, prejudicial,
# Average loss at step 72000: 3.370681
# Average loss at step 74000: 3.340991
# Average loss at step 76000: 3.311781
# Average loss at step 78000: 3.355280
# Average loss at step 80000: 3.379093
# Nearest to UNK: http, carmel, hospitalization, dr, et, schengen, jones, baldwin,
# Nearest to from: through, into, toward, aer, callous, before, within, back,
# Nearest to time: year, diaries, way, oregon, instigator, day, thing, institution,
# Nearest to with: between, eliza, through, in, than, among, galloway, or,
# Nearest to there: they, it, she, he, we, now, still, usually,
# Nearest to such: well, these, tempest, known, regarded, follows, many, robes,
# Nearest to d: b, j, e, talkies, h, pas, p, boring,
# Nearest to new: gifford, old, sabha, duckling, translation, mesoamerica, great, single,
# Nearest to use: share, support, because, rehab, need, cause, basquiat, cruelty,
# Nearest to in: during, within, until, on, at, since, between, numerical,
# Nearest to used: known, found, held, described, called, written, referred, available,
# Nearest to their: its, his, her, our, your, the, acceptors, some,
# Nearest to between: within, with, through, among, in, over, poindexter, into,
# Nearest to during: after, before, in, despite, when, until, throughout, including,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to been: become, be, was, were, recently, being, andromeda, mainframes,
# Average loss at step 82000: 3.407466
# Average loss at step 84000: 3.411914
# Average loss at step 86000: 3.389975
# Average loss at step 88000: 3.355120
# Average loss at step 90000: 3.363361
# Nearest to UNK: seq, et, beaux, toussaint, puma, cecilia, http, texans,
# Nearest to from: through, into, aer, under, before, during, within, in,
# Nearest to time: year, diaries, oregon, period, instigator, way, thing, day,
# Nearest to with: between, in, juggling, by, elevates, eliza, through, paddock,
# Nearest to there: they, it, he, she, we, still, now, said,
# Nearest to such: well, known, these, tempest, many, fives, regarded, certain,
# Nearest to d: b, pas, boring, semiconducting, pebbles, j, vii, manatees,
# Nearest to new: gifford, old, dramatization, translation, objectively, descendents, nadia, var,
# Nearest to use: support, share, existence, because, need, practice, regard, rehab,
# Nearest to in: during, within, of, despite, under, at, with, hodge,
# Nearest to used: known, called, designed, referred, found, held, described, considered,
# Nearest to their: its, his, her, our, your, acceptors, whose, these,
# Nearest to between: within, with, through, into, among, canister, provocative, poindexter,
# Nearest to during: after, before, in, despite, until, at, when, throughout,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to been: become, be, was, were, had, already, being, mainframes,
# Average loss at step 92000: 3.397534
# Average loss at step 94000: 3.254159
# Average loss at step 96000: 3.361686
# Average loss at step 98000: 3.245032
# Average loss at step 100000: 3.357214
# Nearest to UNK: facilitation, trumbo, hitpa, boric, http, wimp, decapitation, prsc,
# Nearest to from: into, through, aer, in, within, under, outside, during,
# Nearest to time: year, way, oregon, day, period, thing, instigator, diaries,
# Nearest to with: between, eliza, ethel, enormous, including, elevates, vardar, into,
# Nearest to there: they, he, it, now, we, she, often, still,
# Nearest to such: well, known, tempest, many, regarded, these, serve, certain,
# Nearest to d: b, c, boring, bittering, j, kosi, h, mathbf,
# Nearest to new: gifford, old, young, different, translation, mesoamerica, fundamental, stem,
# Nearest to use: share, support, cause, allow, need, because, existence, most,
# Nearest to in: during, within, under, until, at, from, through, constructors,
# Nearest to used: designed, referred, known, found, considered, held, called, written,
# Nearest to their: its, his, her, your, our, the, some, whose,
# Nearest to between: with, within, among, through, into, amongst, across, caribou,
# Nearest to during: after, in, despite, before, until, throughout, when, through,
# Nearest to four: six, seven, five, eight, three, two, zero, nine,
# Nearest to been: become, be, was, already, recently, mainframes, pittsburg, andromeda,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
